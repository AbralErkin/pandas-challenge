# %%
#import the pandas library
import pandas as pd

# %%
#create a variable for the csv file and generate data frame using pandas
purchase_file = "purchase_Data.csv"
purchase_df = pd.read_csv(purchase_file, delimiter = ",")

# %%
#display the total number of players:
unique_group_sn = purchase_df.groupby("SN")
unique_SN = unique_group_sn.max()
df_totalPlayers = pd.DataFrame([{"Total Players":unique_SN["Age"].count()}])
df_totalPlayers
# Out:
#    Total Players
# 0            576

# %%
#Purchasing Analysis (Total):

#Find each items
unique_group_item = purchase_df.groupby("Item ID")
unique_item = unique_group_item.max()

itemNum = unique_item["Item Name"].count()
avePrice = purchase_df["Price"].mean()
totalPrice = purchase_df["Price"].sum()
purchaseNum = purchase_df["Purchase ID"].count()

#Create a DataFrame
pur_an = pd.DataFrame([{"Number of Unique Items":itemNum,"Average Price":avePrice,"Number of Purchases": purchaseNum,"Total Revenue":totalPrice }])
pur_an["Average Price"] = pur_an["Average Price"].map("${:.2f}".format)
pur_an["Total Revenue"] = pur_an["Total Revenue"].map("${:.2f}".format)
pur_an
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     183         $3.05                  780      $2379.77

# %%
#Gender Demographics:
#generate groupby object based on gender
unique_gender = unique_SN.groupby("Gender")

#generate dataframe from Unique gender
df_gender = pd.DataFrame(unique_gender["Purchase ID"].count())
df_gender["Percentage of Players"] = unique_gender["Purchase ID"].count()/unique_SN["Age"].count()
df_gender.style.format({"Percentage of Players":"{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_96420c74_5b50_11ea_805f_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase ID</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_96420c74_5b50_11ea_805f_acde48001122level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_96420c74_5b50_11ea_805f_acde48001122row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_96420c74_5b50_11ea_805f_acde48001122row0_col1" class="data row0 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_96420c74_5b50_11ea_805f_acde48001122level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_96420c74_5b50_11ea_805f_acde48001122row1_col0" class="data row1 col0" >484</td>
#                         <td id="T_96420c74_5b50_11ea_805f_acde48001122row1_col1" class="data row1 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_96420c74_5b50_11ea_805f_acde48001122level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_96420c74_5b50_11ea_805f_acde48001122row2_col0" class="data row2 col0" >11</td>
#                         <td id="T_96420c74_5b50_11ea_805f_acde48001122row2_col1" class="data row2 col1" >1.91%</td>
#             </tr>
#     </tbody></table>

# %%
#Purchasing Analysis
gender_group = purchase_df.groupby("Gender")

pur_describe = gender_group["Price"].describe()
total_pur=gender_group["Price"].sum()
ave_total = total_pur/unique_gender["Purchase ID"].count()

pur_describe["Total Purchase Value"] = total_pur
pur_describe["Avg Total Purchase per Person"] = ave_total
pur_analysis=pur_describe[["count","mean","Total Purchase Value","Avg Total Purchase per Person"]]
pur_analysis=pur_analysis.rename(columns = {"count":"Purchase Count","mean":"Average Purchase Price"})
pur_analysis["Purchase Count"] = pur_analysis["Purchase Count"].map("{:.0f}".format)
pur_analysis["Average Purchase Price"] = pur_analysis["Average Purchase Price"].map("${:.2f}".format)
pur_analysis["Total Purchase Value"] = pur_analysis["Total Purchase Value"].map("${:.2f}".format)
pur_analysis["Avg Total Purchase per Person"] = pur_analysis["Avg Total Purchase per Person"].map("${:.2f}".format)
pur_analysis
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                              $1967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %%
#Age Demographics

#Categorize the existing players using the age bins
bins = [0,9,14,19,24,29,34,39,99]
category = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]
unique_SN["Total Count"] = pd.cut(unique_SN["Age"],bins,labels = category)
df_age_demo=unique_SN.groupby(["Total Count"])
age_demo = pd.DataFrame(df_age_demo["Total Count"].count())
age_demo=age_demo.rename_axis("Age Ranges")
age_demo["Percentage of Players"] = df_age_demo["Total Count"].count()/unique_SN["Age"].count()
age_demo.style.format({"Percentage of Players":"{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_9a3c1ebe_5b50_11ea_805f_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Ranges</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a3c1ebe_5b50_11ea_805f_acde48001122level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a3c1ebe_5b50_11ea_805f_acde48001122level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a3c1ebe_5b50_11ea_805f_acde48001122level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a3c1ebe_5b50_11ea_805f_acde48001122level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row3_col0" class="data row3 col0" >258</td>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a3c1ebe_5b50_11ea_805f_acde48001122level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row4_col0" class="data row4 col0" >77</td>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a3c1ebe_5b50_11ea_805f_acde48001122level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row5_col0" class="data row5 col0" >52</td>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a3c1ebe_5b50_11ea_805f_acde48001122level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row6_col0" class="data row6 col0" >31</td>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_9a3c1ebe_5b50_11ea_805f_acde48001122level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_9a3c1ebe_5b50_11ea_805f_acde48001122row7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %%
#Purchasing Analysis (Age)
purchase_df["Age Ranges"] = pd.cut(purchase_df["Age"],bins,labels = category)
purchase_demo=purchase_df.groupby(["Age Ranges"])
purchase_age = purchase_demo["Price"].describe()
purchase_age["Total Purchase Value"] = purchase_demo["Price"].sum()
purchase_age=purchase_age.rename(columns = {"count": "Purchase Count","mean":"Average Purchase Price"})
purchase_age=purchase_age.drop(["std","max","min","25%","75%","50%"],axis = 1)
purchase_age["Avg Total Purchase per Person"]=purchase_demo["Price"].sum()/df_age_demo["Total Count"].count()

#formating the table
purchase_age["Average Purchase Price"]=purchase_age["Average Purchase Price"].map("${:.2f}".format)
purchase_age["Total Purchase Value"]=purchase_age["Total Purchase Value"].map("${:.2f}".format)
purchase_age["Avg Total Purchase per Person"]=purchase_age["Avg Total Purchase per Person"].map("${:.2f}".format)
purchase_age["Purchase Count"]=purchase_age["Purchase Count"].map("{:.0f}".format)
purchase_age
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05             $1114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# 35-39                              $4.76
# 40+                                $3.19

# %%
#Top Spenders analysis
top_spenders_group = purchase_df.groupby(["SN"])
top_spenders = pd.DataFrame(top_spenders_group["Item ID"].count())
top_spenders = top_spenders.rename(columns = {"Item ID":"Purchase Count"})
top_spenders["Average Purchase Price"]=pd.DataFrame(top_spenders_group["Price"].mean())
top_spenders["Total Purchase Value"]=pd.DataFrame(top_spenders_group["Price"].sum())

#sorting and formating
top_spenders = top_spenders.sort_values(by="Total Purchase Value",ascending = False).head()
top_spenders["Total Purchase Value"] = top_spenders["Total Purchase Value"].map("${:.2f}".format)
top_spenders["Average Purchase Price"] = top_spenders["Average Purchase Price"].map("${:.2f}".format)
top_spenders
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %%
#Most Popular Items
top_item_group = purchase_df.groupby(["Item ID","Item Name"])
top_items = top_item_group["Price"]
top_items = pd.DataFrame(top_items.max())

top_items["Purchase Count"] = top_item_group["Price"].count()
top_items = top_items[["Purchase Count","Price"]]
top_items = top_items.rename(columns={"Price":"Item Price"})
top_items["Total Purchase Value"] = top_item_group["Price"].sum()

#sorting and formating
top_items1 = top_items.sort_values(by="Purchase Count",ascending = False).head()
top_items2 = top_items.sort_values(by="Total Purchase Value",ascending = False).head()
top_items1["Item Price"] = top_items1["Item Price"].map("${:.2f}".format)
top_items1["Total Purchase Value"] = top_items1["Total Purchase Value"].map("${:.2f}".format)
top_items1
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77
# 82      Nirvana                                                    $44.10
# 19      Pursuit, Cudgel of Necromancy                               $8.16

# %%
#Most Profitable Items
top_items2["Item Price"] = top_items2["Item Price"].map("${:.2f}".format)
top_items2["Total Purchase Value"] = top_items2["Total Purchase Value"].map("${:.2f}".format)
top_items2
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 92      Final Critic                                               $39.04
# 103     Singed Scalpel                                             $34.80
